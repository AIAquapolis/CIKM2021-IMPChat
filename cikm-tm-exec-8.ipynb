# %%
import sys, os
pbin_dir = os.path.dirname(sys.executable)
# %env PBIN_DIR={pbin_dir}
# Out:
# env: PBIN_DIR=/share_6/work/solepro-moriya/jupyter102/venv-3.9.10-cikm/bin

# %%
#!${PBIN_DIR}/pip install -r requirements.txt

# %%
#!${PBIN_DIR}/pip uninstall -y torchtext
#!${PBIN_DIR}/pip install torch==1.8.2+cu102 torchvision==0.9.2+cu102 torchaudio==0.8.2 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html

# %%
#!rm -rf ./dataset/reddit

# %%
#!ls dataset/

# %%
#%%bash
#cd dataset
#tar -jxvf reddit.tar.bz2

# %%
#!mkdir dataset/reddit
#!mv dataset/*_reddit.pkl dataset/reddit/

# %%
#!cp dataset/reddit/test_reddit.pkl dataset/reddit/dev_reddit.pkl

# %%
#%%bash
#cd dataset
#tar -jxvf reddit_emb.tar.bz2

# %%
#!cp dataset/vocab_and_embeddings.pkl dataset/reddit/vocab_and_embeddings.pkl

# %%
#!mkdir log

# %%
#!${PBIN_DIR}/pip install torchtext==0.9.1 --no-deps
# !cat exec.sh
# Out:
# ts=`date +%Y%m%d%-H%M`
# dataset=reddit
#
# #batch_sizeはcustom embでは30
# CUDA_VISIBLE_DEVICES=6,7 ${PBIN_DIR}/python run.py \
#     --task ${dataset} \
#     --batch_size 30 \
#     --eval_steps 40000 \
#     --emb_len 200 \
#     --max_utterances 29 \
#     --learning_rate 5e-4\
#     --max_words 50 \
#     --n_gpu 2 \
#     --epochs 100 \
#     --n_layer 3 \
#     --max_hop 2 \
#     --score_file_path score_file.txt \
#     --model_file_name ${dataset}_impchat.pt \
#     --is_training True

# %%
# !bash exec.sh
# Out:
# Namespace(task='reddit', is_training=True, max_utterances=29, emb_len=200, max_words=50, gru_hidden=300, learning_rate=0.0005, l2_reg=0.0, epochs=100, save_path='./checkpoint/reddit.IMPChat.2022-08-02_06:14:10.pt', score_file_path='./dataset/reddit/score_file.txtIMPChat.2022-08-02_06:14:10', eval_steps=40000, batch_size=30, local_rank=-1, n_gpu=2, n_layer=3, use_cross_matching=True, n_filters=128, max_hop=2, exact_sigma=0.001, sigma=0.1, type_file='./dataset/reddit/test.type', model_file_name='reddit_impchat.pt')
# Task:  reddit
# IMPChat(
#   (word_embedding): Embedding(61909, 200, padding_idx=0)
#   (selector_transformer): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (linear_word): Linear(in_features=100, out_features=1, bias=True)
#   (linear_score): Linear(in_features=2, out_features=1, bias=True)
#   (transformer_r): ModuleList(
#     (0): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (1): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (2): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#   )
#   (transformer_rp): ModuleList(
#     (0): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (1): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (2): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (3): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#   )
#   (transformer_utt): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (transformer_res): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (transformer_ur): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (transformer_ru): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (cnn_2d_1): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (maxpooling1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (cnn_2d_2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (maxpooling2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (cnn_2d_3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (maxpooling3): MaxPool2d(kernel_size=(3, 3), stride=(3, 3), padding=0, dilation=1, ceil_mode=False)
#   (cnn_2d_4): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#   (cnn_2d_5): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (cnn_2d_6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (affine2): Linear(in_features=576, out_features=200, bias=True)
#   (affine3): Linear(in_features=576, out_features=200, bias=True)
#   (gru_acc): GRU(200, 300, batch_first=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=200, out_features=300, bias=True)
#     (linear2): Linear(in_features=300, out_features=1, bias=True)
#   )
#   (affine_out): Linear(in_features=500, out_features=1, bias=True)
#   (tanh): Tanh()
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# X_utterances:  torch.Size([203960, 29, 50])
# X_responses:  torch.Size([203960, 50])
# y_labels:  torch.Size([203960])
# X_utterances:  torch.Size([256280, 29, 50])
# X_responses:  torch.Size([256280, 50])
# INFO:impchat:IMPChat(
#   (word_embedding): Embedding(61909, 200, padding_idx=0)
#   (selector_transformer): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (linear_word): Linear(in_features=100, out_features=1, bias=True)
#   (linear_score): Linear(in_features=2, out_features=1, bias=True)
#   (transformer_r): ModuleList(
#     (0): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (1): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (2): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#   )
#   (transformer_rp): ModuleList(
#     (0): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (1): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (2): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (3): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#   )
#   (transformer_utt): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (transformer_res): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (transformer_ur): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (transformer_ru): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (cnn_2d_1): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (maxpooling1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (cnn_2d_2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (maxpooling2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (cnn_2d_3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (maxpooling3): MaxPool2d(kernel_size=(3, 3), stride=(3, 3), padding=0, dilation=1, ceil_mode=False)
#   (cnn_2d_4): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#   (cnn_2d_5): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (cnn_2d_6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (affine2): Linear(in_features=576, out_features=200, bias=True)
#   (affine3): Linear(in_features=576, out_features=200, bias=True)
#   (gru_acc): GRU(200, 300, batch_first=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=200, out_features=300, bias=True)
#     (linear2): Linear(in_features=300, out_features=1, bias=True)
#   )
#   (affine_out): Linear(in_features=500, out_features=1, bias=True)
#   (tanh): Tanh()
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# INFO:impchat:Start to train...
# INFO:impchat:train set: 203960
# INFO:impchat:test set: 256280
#
# Epoch  1 / 100
# /share_6/work/solepro-moriya/jupyter102/venv-3.9.10-cikm/lib/python3.9/site-packages/torch/nn/functional.py:1698: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Batch[0] - loss: 1.108554  batch_size:30
# Batch[500] - loss: 0.048026  batch_size:30
# Batch[1000] - loss: 0.232212  batch_size:30
# Batch[1500] - loss: 0.195236  batch_size:30
# Batch[2000] - loss: 0.064547  batch_size:30
# Batch[2500] - loss: 0.303427  batch_size:30
# Batch[3000] - loss: 0.168536  batch_size:30
# Batch[3500] - loss: 0.247874  batch_size:30
# Batch[4000] - loss: 0.199300  batch_size:30
# Batch[4500] - loss: 0.190046  batch_size:30
# Batch[5000] - loss: 0.257543  batch_size:30
# Batch[5500] - loss: 0.161083  batch_size:30
# Batch[6000] - loss: 0.242220  batch_size:30
# Batch[6500] - loss: 0.099584  batch_size:30
# Average loss:0.273623
# 8543it [04:40, 30.41it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6320498289321762	MRR:0.6320498289321762	P@1:0.4852505072576869	R1:0.4852505072576869	R2:0.6156157327922585	R5:0.8324488840330888
# INFO:impchat:Best Result:
#  MAP:0	MRR:0	P@1:0	R1:0	R2:0	R5:0
# save model!!!
#
#
# Epoch  2 / 100
# Batch[0] - loss: 0.183552  batch_size:30
# Batch[500] - loss: 0.102911  batch_size:30
# Batch[1000] - loss: 0.114936  batch_size:30
# Batch[1500] - loss: 0.167869  batch_size:30
# Batch[2000] - loss: 0.382574  batch_size:30
# Batch[2500] - loss: 0.252982  batch_size:30
# Batch[3000] - loss: 0.318478  batch_size:30
# Batch[3500] - loss: 0.213145  batch_size:30
# Batch[4000] - loss: 0.070050  batch_size:30
# Batch[4500] - loss: 0.140172  batch_size:30
# Batch[5000] - loss: 0.213790  batch_size:30
# Batch[5500] - loss: 0.205103  batch_size:30
# Batch[6000] - loss: 0.338219  batch_size:30
# Batch[6500] - loss: 0.233674  batch_size:30
# Average loss:0.227731
# 8543it [04:42, 30.20it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.647150190391987	MRR:0.647150190391987	P@1:0.5017168721710629	R1:0.5017168721710629	R2:0.6360621195567349	R5:0.8486811300140471
# INFO:impchat:Best Result:
#  MAP:0.6320498289321762	MRR:0.6320498289321762	P@1:0.4852505072576869	R1:0.4852505072576869	R2:0.6156157327922585	R5:0.8324488840330888
# save model!!!
#
#
# Epoch  3 / 100
# Batch[0] - loss: 0.036865  batch_size:30
# Batch[500] - loss: 0.333867  batch_size:30
# Batch[1000] - loss: 0.137319  batch_size:30
# Batch[1500] - loss: 0.083769  batch_size:30
# Batch[2000] - loss: 0.304651  batch_size:30
# Batch[2500] - loss: 0.140212  batch_size:30
# Batch[3000] - loss: 0.235484  batch_size:30
# Batch[3500] - loss: 0.303046  batch_size:30
# Batch[4000] - loss: 0.218328  batch_size:30
# Batch[4500] - loss: 0.046840  batch_size:30
# Batch[5000] - loss: 0.255130  batch_size:30
# Batch[5500] - loss: 0.168549  batch_size:30
# Batch[6000] - loss: 0.265286  batch_size:30
# Batch[6500] - loss: 0.351294  batch_size:30
# Average loss:0.183892
# 8543it [04:42, 30.24it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6338058447977597	MRR:0.6338058447977597	P@1:0.4872405181832371	R1:0.4872405181832371	R2:0.6178398626502263	R5:0.8336975183393164
#
# Epoch  4 / 100
# Batch[0] - loss: 0.060057  batch_size:30
# Batch[500] - loss: 0.039649  batch_size:30
# Batch[1000] - loss: 0.063858  batch_size:30
# Batch[1500] - loss: 0.053237  batch_size:30
# Batch[2000] - loss: 0.022792  batch_size:30
# Batch[2500] - loss: 0.121437  batch_size:30
# Batch[3000] - loss: 0.050749  batch_size:30
# Batch[3500] - loss: 0.047487  batch_size:30
# Batch[4000] - loss: 0.219629  batch_size:30
# Batch[4500] - loss: 0.123081  batch_size:30
# Batch[5000] - loss: 0.213594  batch_size:30
# Batch[5500] - loss: 0.224535  batch_size:30
# Batch[6000] - loss: 0.109683  batch_size:30
# Batch[6500] - loss: 0.034489  batch_size:30
# Average loss:0.132495
# 8543it [04:44, 30.08it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6066945472586096	MRR:0.6066945472586096	P@1:0.455322303730295	R1:0.455322303730295	R2:0.5862728265959107	R5:0.8104026845637584
#
# Epoch  5 / 100
# Batch[0] - loss: 0.102690  batch_size:30
# Batch[500] - loss: 0.006312  batch_size:30
# Batch[1000] - loss: 0.041714  batch_size:30
# Batch[1500] - loss: 0.225373  batch_size:30
# Batch[2000] - loss: 0.073272  batch_size:30
# Batch[2500] - loss: 0.223941  batch_size:30
# Batch[3000] - loss: 0.326669  batch_size:30
# Batch[3500] - loss: 0.026854  batch_size:30
# Batch[4000] - loss: 0.056141  batch_size:30
# Batch[4500] - loss: 0.023011  batch_size:30
# Batch[5000] - loss: 0.251586  batch_size:30
# Batch[5500] - loss: 0.267960  batch_size:30
# Batch[6000] - loss: 0.136307  batch_size:30
# Batch[6500] - loss: 0.102294  batch_size:30
# Average loss:0.088033
# 8543it [04:43, 30.17it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.5880427781122629	MRR:0.5880427781122629	P@1:0.4339784610582176	R1:0.4339784610582176	R2:0.565865459653504	R5:0.7873419697206181
#
# Epoch  6 / 100
# Batch[0] - loss: 0.008933  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  0.00025
# INFO:impchat:lr to:0.00025
# Batch[500] - loss: 0.240504  batch_size:30
# Batch[1000] - loss: 0.162565  batch_size:30
# Batch[1500] - loss: 0.327530  batch_size:30
# Batch[2000] - loss: 0.233527  batch_size:30
# Batch[2500] - loss: 0.682017  batch_size:30
# Batch[3000] - loss: 0.229364  batch_size:30
# Batch[3500] - loss: 0.084298  batch_size:30
# Batch[4000] - loss: 0.081389  batch_size:30
# Batch[4500] - loss: 0.093428  batch_size:30
# Batch[5000] - loss: 0.149889  batch_size:30
# Batch[5500] - loss: 0.135578  batch_size:30
# Batch[6000] - loss: 0.185695  batch_size:30
# Batch[6500] - loss: 0.098705  batch_size:30
# Average loss:0.169582
# 8543it [04:43, 30.11it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6374895018098068	MRR:0.6374895018098068	P@1:0.4907523021695021	R1:0.4907523021695021	R2:0.6228343998751366	R5:0.83935539253941
#
# Epoch  7 / 100
# Batch[0] - loss: 0.063590  batch_size:30
# Batch[500] - loss: 0.022040  batch_size:30
# Batch[1000] - loss: 0.057494  batch_size:30
# Batch[1500] - loss: 0.097318  batch_size:30
# Batch[2000] - loss: 0.181662  batch_size:30
# Batch[2500] - loss: 0.171915  batch_size:30
# Batch[3000] - loss: 0.041767  batch_size:30
# Batch[3500] - loss: 0.036289  batch_size:30
# Batch[4000] - loss: 0.076779  batch_size:30
# Batch[4500] - loss: 0.144531  batch_size:30
# Batch[5000] - loss: 0.176663  batch_size:30
# Batch[5500] - loss: 0.041586  batch_size:30
# Batch[6000] - loss: 0.149908  batch_size:30
# Batch[6500] - loss: 0.161726  batch_size:30
# Average loss:0.128771
# 8543it [04:43, 30.13it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6250018890549058	MRR:0.6250018890549058	P@1:0.47678320586858125	R1:0.47678320586858125	R2:0.6083580458873108	R5:0.8244108006867489
#
# Epoch  8 / 100
# Batch[0] - loss: 0.061328  batch_size:30
# Batch[500] - loss: 0.011289  batch_size:30
# Batch[1000] - loss: 0.086063  batch_size:30
# Batch[1500] - loss: 0.012017  batch_size:30
# Batch[2000] - loss: 0.138055  batch_size:30
# Batch[2500] - loss: 0.273221  batch_size:30
# Batch[3000] - loss: 0.068420  batch_size:30
# Batch[3500] - loss: 0.004057  batch_size:30
# Batch[4000] - loss: 0.027521  batch_size:30
# Batch[4500] - loss: 0.030576  batch_size:30
# Batch[5000] - loss: 0.059798  batch_size:30
# Batch[5500] - loss: 0.075535  batch_size:30
# Batch[6000] - loss: 0.191452  batch_size:30
# Batch[6500] - loss: 0.024918  batch_size:30
# Average loss:0.090106
# 8543it [04:43, 30.14it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6082685325574267	MRR:0.6082685325574267	P@1:0.4560636803496176	R1:0.4560636803496176	R2:0.5906040268456376	R5:0.8112611206492898
#
# Epoch  9 / 100
# Batch[0] - loss: 0.032953  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  0.000125
# INFO:impchat:lr to:0.000125
# Batch[500] - loss: 0.142847  batch_size:30
# Batch[1000] - loss: 0.351612  batch_size:30
# Batch[1500] - loss: 0.241924  batch_size:30
# Batch[2000] - loss: 0.111122  batch_size:30
# Batch[2500] - loss: 0.218359  batch_size:30
# Batch[3000] - loss: 0.092222  batch_size:30
# Batch[3500] - loss: 0.031916  batch_size:30
# Batch[4000] - loss: 0.302546  batch_size:30
# Batch[4500] - loss: 0.138409  batch_size:30
# Batch[5000] - loss: 0.304732  batch_size:30
# Batch[5500] - loss: 0.053556  batch_size:30
# Batch[6000] - loss: 0.027492  batch_size:30
# Batch[6500] - loss: 0.061748  batch_size:30
# Average loss:0.165469
# 8543it [04:41, 30.30it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6403322042359718	MRR:0.6403322042359718	P@1:0.4921179959419385	R1:0.4921179959419385	R2:0.6276728578117684	R5:0.8467301389105666
#
# Epoch  10 / 100
# Batch[0] - loss: 0.025506  batch_size:30
# Batch[500] - loss: 0.070359  batch_size:30
# Batch[1000] - loss: 0.152485  batch_size:30
# Batch[1500] - loss: 0.270194  batch_size:30
# Batch[2000] - loss: 0.118263  batch_size:30
# Batch[2500] - loss: 0.112075  batch_size:30
# Batch[3000] - loss: 0.172688  batch_size:30
# Batch[3500] - loss: 0.099702  batch_size:30
# Batch[4000] - loss: 0.139401  batch_size:30
# Batch[4500] - loss: 0.224420  batch_size:30
# Batch[5000] - loss: 0.026098  batch_size:30
# Batch[5500] - loss: 0.221999  batch_size:30
# Batch[6000] - loss: 0.135278  batch_size:30
# Batch[6500] - loss: 0.211729  batch_size:30
# Average loss:0.135705
# 8543it [04:42, 30.20it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6336468235387658	MRR:0.6336468235387658	P@1:0.4848993288590604	R1:0.4848993288590604	R2:0.6196347744654285	R5:0.8376775401904167
#
# Epoch  11 / 100
# Batch[0] - loss: 0.032857  batch_size:30
# Batch[500] - loss: 0.035212  batch_size:30
# Batch[1000] - loss: 0.133206  batch_size:30
# Batch[1500] - loss: 0.113957  batch_size:30
# Batch[2000] - loss: 0.170836  batch_size:30
# Batch[2500] - loss: 0.229522  batch_size:30
# Batch[3000] - loss: 0.054267  batch_size:30
# Batch[3500] - loss: 0.029369  batch_size:30
# Batch[4000] - loss: 0.043246  batch_size:30
# Batch[4500] - loss: 0.181312  batch_size:30
# Batch[5000] - loss: 0.127145  batch_size:30
# Batch[5500] - loss: 0.205387  batch_size:30
# Batch[6000] - loss: 0.072871  batch_size:30
# Batch[6500] - loss: 0.051081  batch_size:30
# Average loss:0.105340
# 8543it [04:43, 30.18it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6195383862145101	MRR:0.6195383862145101	P@1:0.4680427657249883	R1:0.4680427657249883	R2:0.60441704385828	R5:0.8243717808646792
#
# Epoch  12 / 100
# Batch[0] - loss: 0.148389  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  6.25e-05
# INFO:impchat:lr to:6.25e-05
# Batch[500] - loss: 0.383899  batch_size:30
# Batch[1000] - loss: 0.166939  batch_size:30
# Batch[1500] - loss: 0.234112  batch_size:30
# Batch[2000] - loss: 0.317063  batch_size:30
# Batch[2500] - loss: 0.079871  batch_size:30
# Batch[3000] - loss: 0.039086  batch_size:30
# Batch[3500] - loss: 0.194634  batch_size:30
# Batch[4000] - loss: 0.386046  batch_size:30
# Batch[4500] - loss: 0.085437  batch_size:30
# Batch[5000] - loss: 0.096793  batch_size:30
# Batch[5500] - loss: 0.175007  batch_size:30
# Batch[6000] - loss: 0.047763  batch_size:30
# Batch[6500] - loss: 0.164827  batch_size:30
# Average loss:0.166405
# 8543it [04:42, 30.19it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6433428777057112	MRR:0.6433428777057112	P@1:0.4962150772592477	R1:0.4962150772592477	R2:0.6300140471359451	R5:0.8477056344623068
#
# Epoch  13 / 100
# Batch[0] - loss: 0.088501  batch_size:30
# Batch[500] - loss: 0.058526  batch_size:30
# Batch[1000] - loss: 0.112007  batch_size:30
# Batch[1500] - loss: 0.127432  batch_size:30
# Batch[2000] - loss: 0.209146  batch_size:30
# Batch[2500] - loss: 0.278841  batch_size:30
# Batch[3000] - loss: 0.097968  batch_size:30
# Batch[3500] - loss: 0.114452  batch_size:30
# Batch[4000] - loss: 0.040395  batch_size:30
# Batch[4500] - loss: 0.090081  batch_size:30
# Batch[5000] - loss: 0.117127  batch_size:30
# Batch[5500] - loss: 0.041192  batch_size:30
# Batch[6000] - loss: 0.039937  batch_size:30
# Batch[6500] - loss: 0.218156  batch_size:30
# Average loss:0.145622
# 8543it [04:42, 30.19it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6373480549548005	MRR:0.6373480549548005	P@1:0.4898938660839707	R1:0.4898938660839707	R2:0.6231075386296239	R5:0.841267363820821
#
# Epoch  14 / 100
# Batch[0] - loss: 0.168759  batch_size:30
# Batch[500] - loss: 0.112513  batch_size:30
# Batch[1000] - loss: 0.025409  batch_size:30
# Batch[1500] - loss: 0.203664  batch_size:30
# Batch[2000] - loss: 0.025786  batch_size:30
# Batch[2500] - loss: 0.141333  batch_size:30
# Batch[3000] - loss: 0.160810  batch_size:30
# Batch[3500] - loss: 0.030323  batch_size:30
# Batch[4000] - loss: 0.046097  batch_size:30
# Batch[4500] - loss: 0.089573  batch_size:30
# Batch[5000] - loss: 0.075273  batch_size:30
# Batch[5500] - loss: 0.195928  batch_size:30
# Batch[6000] - loss: 0.150601  batch_size:30
# Batch[6500] - loss: 0.191358  batch_size:30
# Average loss:0.126538
# 8543it [04:42, 30.24it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6301842943358359	MRR:0.6301842943358359	P@1:0.4814655845169346	R1:0.4814655845169346	R2:0.6166692679881379	R5:0.8322537849227407
#
# Epoch  15 / 100
# Batch[0] - loss: 0.114374  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  3.125e-05
# INFO:impchat:lr to:3.125e-05
# Batch[500] - loss: 0.297909  batch_size:30
# Batch[1000] - loss: 0.443897  batch_size:30
# Batch[1500] - loss: 0.084051  batch_size:30
# Batch[2000] - loss: 0.088217  batch_size:30
# Batch[2500] - loss: 0.066275  batch_size:30
# Batch[3000] - loss: 0.092460  batch_size:30
# Batch[3500] - loss: 0.180030  batch_size:30
# Batch[4000] - loss: 0.114783  batch_size:30
# Batch[4500] - loss: 0.100342  batch_size:30
# Batch[5000] - loss: 0.133043  batch_size:30
# Batch[5500] - loss: 0.102343  batch_size:30
# Batch[6000] - loss: 0.204741  batch_size:30
# Batch[6500] - loss: 0.101561  batch_size:30
# Average loss:0.168530
# 8543it [04:42, 30.29it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6463369677510742	MRR:0.6463369677510742	P@1:0.5002731387544873	R1:0.5002731387544873	R2:0.6336819104104885	R5:0.8491493678788825
#
# Epoch  16 / 100
# Batch[0] - loss: 0.177051  batch_size:30
# Batch[500] - loss: 0.252131  batch_size:30
# Batch[1000] - loss: 0.113008  batch_size:30
# Batch[1500] - loss: 0.251185  batch_size:30
# Batch[2000] - loss: 0.059346  batch_size:30
# Batch[2500] - loss: 0.203355  batch_size:30
# Batch[3000] - loss: 0.046176  batch_size:30
# Batch[3500] - loss: 0.050821  batch_size:30
# Batch[4000] - loss: 0.062796  batch_size:30
# Batch[4500] - loss: 0.088648  batch_size:30
# Batch[5000] - loss: 0.204560  batch_size:30
# Batch[5500] - loss: 0.070257  batch_size:30
# Batch[6000] - loss: 0.183969  batch_size:30
# Batch[6500] - loss: 0.224041  batch_size:30
# Average loss:0.153657
# 8543it [06:51, 20.74it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6426094908594773	MRR:0.6426094908594773	P@1:0.4952395817075074	R1:0.4952395817075074	R2:0.6304822850007804	R5:0.8458717028250351
#
# Epoch  17 / 100
# Batch[0] - loss: 0.030560  batch_size:30
# Batch[500] - loss: 0.220591  batch_size:30
# Batch[1000] - loss: 0.029427  batch_size:30
# Batch[1500] - loss: 0.056217  batch_size:30
# Batch[2000] - loss: 0.309505  batch_size:30
# Batch[2500] - loss: 0.039261  batch_size:30
# Batch[3000] - loss: 0.067869  batch_size:30
# Batch[3500] - loss: 0.025519  batch_size:30
# Batch[4000] - loss: 0.134114  batch_size:30
# Batch[4500] - loss: 0.111604  batch_size:30
# Batch[5000] - loss: 0.065783  batch_size:30
# Batch[5500] - loss: 0.046165  batch_size:30
# Batch[6000] - loss: 0.115187  batch_size:30
# Batch[6500] - loss: 0.239989  batch_size:30
# Average loss:0.142378
# 8543it [04:46, 29.80it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6380478104305822	MRR:0.6380478104305822	P@1:0.49036210394880597	R1:0.49036210394880597	R2:0.6251365693772436	R5:0.8416185422194474
#
# Epoch  18 / 100
# Batch[0] - loss: 0.195422  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  1.5625e-05
# INFO:impchat:lr to:1.5625e-05
# Batch[500] - loss: 0.132191  batch_size:30
# Batch[1000] - loss: 0.148354  batch_size:30
# Batch[1500] - loss: 0.255070  batch_size:30
# Batch[2000] - loss: 0.104421  batch_size:30
# Batch[2500] - loss: 0.252606  batch_size:30
# Batch[3000] - loss: 0.122226  batch_size:30
# Batch[3500] - loss: 0.268613  batch_size:30
# Batch[4000] - loss: 0.187368  batch_size:30
# Batch[4500] - loss: 0.083366  batch_size:30
# Batch[5000] - loss: 0.041713  batch_size:30
# Batch[5500] - loss: 0.067942  batch_size:30
# Batch[6000] - loss: 0.236932  batch_size:30
# Batch[6500] - loss: 0.159116  batch_size:30
# Average loss:0.171161
# 8543it [04:43, 30.09it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487418275150729	MRR:0.6487418275150729	P@1:0.5037849227407523	R1:0.5037849227407523	R2:0.6348915248946465	R5:0.8527391915092867
# INFO:impchat:Best Result:
#  MAP:0.647150190391987	MRR:0.647150190391987	P@1:0.5017168721710629	R1:0.5017168721710629	R2:0.6360621195567349	R5:0.8486811300140471
# save model!!!
#
#
# Epoch  19 / 100
# Batch[0] - loss: 0.166540  batch_size:30
# Batch[500] - loss: 0.197975  batch_size:30
# Batch[1000] - loss: 0.358541  batch_size:30
# Batch[1500] - loss: 0.101793  batch_size:30
# Batch[2000] - loss: 0.183295  batch_size:30
# Batch[2500] - loss: 0.221527  batch_size:30
# Batch[3000] - loss: 0.222363  batch_size:30
# Batch[3500] - loss: 0.117015  batch_size:30
# Batch[4000] - loss: 0.046693  batch_size:30
# Batch[4500] - loss: 0.073207  batch_size:30
# Batch[5000] - loss: 0.249880  batch_size:30
# Batch[5500] - loss: 0.181603  batch_size:30
# Batch[6000] - loss: 0.122585  batch_size:30
# Batch[6500] - loss: 0.074605  batch_size:30
# Average loss:0.160084
# 8543it [04:42, 30.21it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6474603670093246	MRR:0.6474603670093246	P@1:0.501911971281411	R1:0.501911971281411	R2:0.6346964257842984	R5:0.8493834868113002
#
# Epoch  20 / 100
# Batch[0] - loss: 0.141505  batch_size:30
# Batch[500] - loss: 0.061192  batch_size:30
# Batch[1000] - loss: 0.053347  batch_size:30
# Batch[1500] - loss: 0.160228  batch_size:30
# Batch[2000] - loss: 0.196450  batch_size:30
# Batch[2500] - loss: 0.257790  batch_size:30
# Batch[3000] - loss: 0.054543  batch_size:30
# Batch[3500] - loss: 0.324376  batch_size:30
# Batch[4000] - loss: 0.249089  batch_size:30
# Batch[4500] - loss: 0.215458  batch_size:30
# Batch[5000] - loss: 0.264334  batch_size:30
# Batch[5500] - loss: 0.025906  batch_size:30
# Batch[6000] - loss: 0.307891  batch_size:30
# Batch[6500] - loss: 0.283313  batch_size:30
# Average loss:0.152887
# 8543it [04:43, 30.10it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6443409025594788	MRR:0.6443409025594788	P@1:0.49804900889651943	R1:0.49804900889651943	R2:0.6305993444669892	R5:0.8473154362416108
#
# Epoch  21 / 100
# Batch[0] - loss: 0.274671  batch_size:30
# Batch[500] - loss: 0.368672  batch_size:30
# Batch[1000] - loss: 0.167462  batch_size:30
# Batch[1500] - loss: 0.146025  batch_size:30
# Batch[2000] - loss: 0.087719  batch_size:30
# Batch[2500] - loss: 0.337182  batch_size:30
# Batch[3000] - loss: 0.102492  batch_size:30
# Batch[3500] - loss: 0.224516  batch_size:30
# Batch[4000] - loss: 0.300958  batch_size:30
# Batch[4500] - loss: 0.225979  batch_size:30
# Batch[5000] - loss: 0.089924  batch_size:30
# Batch[5500] - loss: 0.299500  batch_size:30
# Batch[6000] - loss: 0.044054  batch_size:30
# Batch[6500] - loss: 0.023990  batch_size:30
# Average loss:0.146506
# 8543it [04:42, 30.27it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6402504948704677	MRR:0.6402504948704677	P@1:0.49250819416263464	R1:0.49250819416263464	R2:0.627711877633838	R5:0.8439207117215546
#
# Epoch  22 / 100
# Batch[0] - loss: 0.081004  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  7.8125e-06
# INFO:impchat:lr to:7.8125e-06
# Batch[500] - loss: 0.199541  batch_size:30
# Batch[1000] - loss: 0.083623  batch_size:30
# Batch[1500] - loss: 0.158882  batch_size:30
# Batch[2000] - loss: 0.284088  batch_size:30
# Batch[2500] - loss: 0.055919  batch_size:30
# Batch[3000] - loss: 0.108379  batch_size:30
# Batch[3500] - loss: 0.205899  batch_size:30
# Batch[4000] - loss: 0.321912  batch_size:30
# Batch[4500] - loss: 0.274116  batch_size:30
# Batch[5000] - loss: 0.250726  batch_size:30
# Batch[5500] - loss: 0.317200  batch_size:30
# Batch[6000] - loss: 0.060215  batch_size:30
# Batch[6500] - loss: 0.221264  batch_size:30
# Average loss:0.161057
# 8543it [04:43, 30.19it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6479751963997994	MRR:0.6479751963997994	P@1:0.5027704073669425	R1:0.5027704073669425	R2:0.6345013266739503	R5:0.8509832995161543
#
# Epoch  23 / 100
# Batch[0] - loss: 0.380809  batch_size:30
# Batch[500] - loss: 0.398107  batch_size:30
# Batch[1000] - loss: 0.272235  batch_size:30
# Batch[1500] - loss: 0.139759  batch_size:30
# Batch[2000] - loss: 0.156977  batch_size:30
# Batch[2500] - loss: 0.323877  batch_size:30
# Batch[3000] - loss: 0.065196  batch_size:30
# Batch[3500] - loss: 0.084343  batch_size:30
# Batch[4000] - loss: 0.191568  batch_size:30
# Batch[4500] - loss: 0.048596  batch_size:30
# Batch[5000] - loss: 0.067575  batch_size:30
# Batch[5500] - loss: 0.324544  batch_size:30
# Batch[6000] - loss: 0.075010  batch_size:30
# Batch[6500] - loss: 0.252476  batch_size:30
# Average loss:0.156781
# 8543it [04:41, 30.30it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6455823832316598	MRR:0.6455823832316598	P@1:0.49980490088965196	R1:0.49980490088965196	R2:0.6318869985952864	R5:0.8470032776650539
#
# Epoch  24 / 100
# Batch[0] - loss: 0.177785  batch_size:30
# Batch[500] - loss: 0.241959  batch_size:30
# Batch[1000] - loss: 0.219553  batch_size:30
# Batch[1500] - loss: 0.378758  batch_size:30
# Batch[2000] - loss: 0.170356  batch_size:30
# Batch[2500] - loss: 0.166983  batch_size:30
# Batch[3000] - loss: 0.252301  batch_size:30
# Batch[3500] - loss: 0.104381  batch_size:30
# Batch[4000] - loss: 0.371591  batch_size:30
# Batch[4500] - loss: 0.162830  batch_size:30
# Batch[5000] - loss: 0.177040  batch_size:30
# Batch[5500] - loss: 0.085815  batch_size:30
# Batch[6000] - loss: 0.039929  batch_size:30
# Batch[6500] - loss: 0.064875  batch_size:30
# Average loss:0.153194
# 8543it [04:43, 30.13it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6445849312879773	MRR:0.6445849312879773	P@1:0.4986733260496332	R1:0.4986733260496332	R2:0.6304042453566412	R5:0.8467301389105666
#
# Epoch  25 / 100
# Batch[0] - loss: 0.206774  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  3.90625e-06
# INFO:impchat:lr to:3.90625e-06
# Batch[500] - loss: 0.100464  batch_size:30
# Batch[1000] - loss: 0.149572  batch_size:30
# Batch[1500] - loss: 0.378851  batch_size:30
# Batch[2000] - loss: 0.436441  batch_size:30
# Batch[2500] - loss: 0.025627  batch_size:30
# Batch[3000] - loss: 0.163286  batch_size:30
# Batch[3500] - loss: 0.041984  batch_size:30
# Batch[4000] - loss: 0.053425  batch_size:30
# Batch[4500] - loss: 0.059611  batch_size:30
# Batch[5000] - loss: 0.045607  batch_size:30
# Batch[5500] - loss: 0.146661  batch_size:30
# Batch[6000] - loss: 0.188138  batch_size:30
# Batch[6500] - loss: 0.271714  batch_size:30
# Average loss:0.161401
# 8543it [04:42, 30.26it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6485228210216784	MRR:0.6485228210216784	P@1:0.5032386452317777	R1:0.5032386452317777	R2:0.6357499609801779	R5:0.8521929140003122
#
# Epoch  26 / 100
# Batch[0] - loss: 0.138238  batch_size:30
# Batch[500] - loss: 0.055928  batch_size:30
# Batch[1000] - loss: 0.131417  batch_size:30
# Batch[1500] - loss: 0.343571  batch_size:30
# Batch[2000] - loss: 0.039028  batch_size:30
# Batch[2500] - loss: 0.083147  batch_size:30
# Batch[3000] - loss: 0.046962  batch_size:30
# Batch[3500] - loss: 0.049179  batch_size:30
# Batch[4000] - loss: 0.207906  batch_size:30
# Batch[4500] - loss: 0.122982  batch_size:30
# Batch[5000] - loss: 0.387971  batch_size:30
# Batch[5500] - loss: 0.093744  batch_size:30
# Batch[6000] - loss: 0.049363  batch_size:30
# Batch[6500] - loss: 0.103094  batch_size:30
# Average loss:0.159160
# 8543it [04:43, 30.17it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.647449806882877	MRR:0.647449806882877	P@1:0.501911971281411	R1:0.501911971281411	R2:0.634033088809115	R5:0.8504760418292493
#
# Epoch  27 / 100
# Batch[0] - loss: 0.082031  batch_size:30
# Batch[500] - loss: 0.213559  batch_size:30
# Batch[1000] - loss: 0.131446  batch_size:30
# Batch[1500] - loss: 0.099339  batch_size:30
# Batch[2000] - loss: 0.086913  batch_size:30
# Batch[2500] - loss: 0.048616  batch_size:30
# Batch[3000] - loss: 0.116905  batch_size:30
# Batch[3500] - loss: 0.162427  batch_size:30
# Batch[4000] - loss: 0.055300  batch_size:30
# Batch[4500] - loss: 0.027002  batch_size:30
# Batch[5000] - loss: 0.057153  batch_size:30
# Batch[5500] - loss: 0.072771  batch_size:30
# Batch[6000] - loss: 0.132652  batch_size:30
# Batch[6500] - loss: 0.243475  batch_size:30
# Average loss:0.156987
# 8543it [04:42, 30.21it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6468539958775519	MRR:0.6468539958775519	P@1:0.5014437334165757	R1:0.5014437334165757	R2:0.6334868113001405	R5:0.8485640705478383
#
# Epoch  28 / 100
# Batch[0] - loss: 0.206045  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  1.953125e-06
# INFO:impchat:lr to:1.953125e-06
# Batch[500] - loss: 0.052156  batch_size:30
# Batch[1000] - loss: 0.230920  batch_size:30
# Batch[1500] - loss: 0.153760  batch_size:30
# Batch[2000] - loss: 0.228520  batch_size:30
# Batch[2500] - loss: 0.288261  batch_size:30
# Batch[3000] - loss: 0.110881  batch_size:30
# Batch[3500] - loss: 0.257823  batch_size:30
# Batch[4000] - loss: 0.173155  batch_size:30
# Batch[4500] - loss: 0.040678  batch_size:30
# Batch[5000] - loss: 0.038712  batch_size:30
# Batch[5500] - loss: 0.122835  batch_size:30
# Batch[6000] - loss: 0.171298  batch_size:30
# Batch[6500] - loss: 0.399177  batch_size:30
# Average loss:0.161737
# 8543it [04:42, 30.23it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6488043831028345	MRR:0.6488043831028345	P@1:0.5035898236304043	R1:0.5035898236304043	R2:0.6360230997346652	R5:0.8527391915092867
# INFO:impchat:Best Result:
#  MAP:0.6487418275150729	MRR:0.6487418275150729	P@1:0.5037849227407523	R1:0.5037849227407523	R2:0.6348915248946465	R5:0.8527391915092867
# save model!!!
#
#
# Epoch  29 / 100
# Batch[0] - loss: 0.394268  batch_size:30
# Batch[500] - loss: 0.166286  batch_size:30
# Batch[1000] - loss: 0.142279  batch_size:30
# Batch[1500] - loss: 0.053375  batch_size:30
# Batch[2000] - loss: 0.142214  batch_size:30
# Batch[2500] - loss: 0.131454  batch_size:30
# Batch[3000] - loss: 0.160453  batch_size:30
# Batch[3500] - loss: 0.525993  batch_size:30
# Batch[4000] - loss: 0.157599  batch_size:30
# Batch[4500] - loss: 0.169047  batch_size:30
# Batch[5000] - loss: 0.173047  batch_size:30
# Batch[5500] - loss: 0.140231  batch_size:30
# Batch[6000] - loss: 0.054361  batch_size:30
# Batch[6500] - loss: 0.028425  batch_size:30
# Average loss:0.160457
# 8543it [04:41, 30.31it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6484776540292272	MRR:0.6484776540292272	P@1:0.5032386452317777	R1:0.5032386452317777	R2:0.6353987825815515	R5:0.8519587950678945
#
# Epoch  30 / 100
# Batch[0] - loss: 0.198554  batch_size:30
# Batch[500] - loss: 0.264573  batch_size:30
# Batch[1000] - loss: 0.121694  batch_size:30
# Batch[1500] - loss: 0.239009  batch_size:30
# Batch[2000] - loss: 0.313343  batch_size:30
# Batch[2500] - loss: 0.362739  batch_size:30
# Batch[3000] - loss: 0.054193  batch_size:30
# Batch[3500] - loss: 0.071661  batch_size:30
# Batch[4000] - loss: 0.147657  batch_size:30
# Batch[4500] - loss: 0.131877  batch_size:30
# Batch[5000] - loss: 0.087352  batch_size:30
# Batch[5500] - loss: 0.040103  batch_size:30
# Batch[6000] - loss: 0.236081  batch_size:30
# Batch[6500] - loss: 0.131940  batch_size:30
# Average loss:0.159434
# 8543it [04:42, 30.19it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6479164963420747	MRR:0.6479164963420747	P@1:0.5024192289683159	R1:0.5024192289683159	R2:0.6345013266739503	R5:0.8514515373809896
#
# Epoch  31 / 100
# Batch[0] - loss: 0.272444  batch_size:30
# Batch[500] - loss: 0.163293  batch_size:30
# Batch[1000] - loss: 0.274195  batch_size:30
# Batch[1500] - loss: 0.349767  batch_size:30
# Batch[2000] - loss: 0.065656  batch_size:30
# Batch[2500] - loss: 0.169830  batch_size:30
# Batch[3000] - loss: 0.238781  batch_size:30
# Batch[3500] - loss: 0.125975  batch_size:30
# Batch[4000] - loss: 0.101087  batch_size:30
# Batch[4500] - loss: 0.283847  batch_size:30
# Batch[5000] - loss: 0.132491  batch_size:30
# Batch[5500] - loss: 0.048267  batch_size:30
# Batch[6000] - loss: 0.148471  batch_size:30
# Batch[6500] - loss: 0.138861  batch_size:30
# Average loss:0.158254
# 8543it [04:42, 30.22it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.64753013816736	MRR:0.64753013816736	P@1:0.5020680505696894	R1:0.5020680505696894	R2:0.6339160293429063	R5:0.8503589823630404
#
# Epoch  32 / 100
# Batch[0] - loss: 0.333719  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  9.765625e-07
# INFO:impchat:lr to:9.765625e-07
# Batch[500] - loss: 0.082760  batch_size:30
# Batch[1000] - loss: 0.068794  batch_size:30
# Batch[1500] - loss: 0.105326  batch_size:30
# Batch[2000] - loss: 0.147956  batch_size:30
# Batch[2500] - loss: 0.156249  batch_size:30
# Batch[3000] - loss: 0.143554  batch_size:30
# Batch[3500] - loss: 0.086281  batch_size:30
# Batch[4000] - loss: 0.200038  batch_size:30
# Batch[4500] - loss: 0.330977  batch_size:30
# Batch[5000] - loss: 0.247502  batch_size:30
# Batch[5500] - loss: 0.254490  batch_size:30
# Batch[6000] - loss: 0.105614  batch_size:30
# Batch[6500] - loss: 0.334077  batch_size:30
# Average loss:0.160822
# 8543it [04:43, 30.12it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487759543753271	MRR:0.6487759543753271	P@1:0.5039019822069611	R1:0.5039019822069611	R2:0.6350085843608553	R5:0.8525440923989387
#
# Epoch  33 / 100
# Batch[0] - loss: 0.469073  batch_size:30
# Batch[500] - loss: 0.233298  batch_size:30
# Batch[1000] - loss: 0.261538  batch_size:30
# Batch[1500] - loss: 0.311203  batch_size:30
# Batch[2000] - loss: 0.187771  batch_size:30
# Batch[2500] - loss: 0.115052  batch_size:30
# Batch[3000] - loss: 0.199860  batch_size:30
# Batch[3500] - loss: 0.046161  batch_size:30
# Batch[4000] - loss: 0.618813  batch_size:30
# Batch[4500] - loss: 0.246314  batch_size:30
# Batch[5000] - loss: 0.042845  batch_size:30
# Batch[5500] - loss: 0.243291  batch_size:30
# Batch[6000] - loss: 0.206722  batch_size:30
# Batch[6500] - loss: 0.060811  batch_size:30
# Average loss:0.160000
# 8543it [04:42, 30.23it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.648526212030025	MRR:0.648526212030025	P@1:0.5032776650538473	R1:0.5032776650538473	R2:0.6355938816918995	R5:0.8522709536444514
#
# Epoch  34 / 100
# Batch[0] - loss: 0.056461  batch_size:30
# Batch[500] - loss: 0.040776  batch_size:30
# Batch[1000] - loss: 0.059601  batch_size:30
# Batch[1500] - loss: 0.110953  batch_size:30
# Batch[2000] - loss: 0.154900  batch_size:30
# Batch[2500] - loss: 0.167989  batch_size:30
# Batch[3000] - loss: 0.161635  batch_size:30
# Batch[3500] - loss: 0.132427  batch_size:30
# Batch[4000] - loss: 0.068902  batch_size:30
# Batch[4500] - loss: 0.285709  batch_size:30
# Batch[5000] - loss: 0.336771  batch_size:30
# Batch[5500] - loss: 0.134188  batch_size:30
# Batch[6000] - loss: 0.034965  batch_size:30
# Batch[6500] - loss: 0.133867  batch_size:30
# Average loss:0.159297
# 8543it [04:42, 30.26it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6481498720397861	MRR:0.6481498720397861	P@1:0.5027704073669425	R1:0.5027704073669425	R2:0.6347744654284376	R5:0.851607616669268
#
# Epoch  35 / 100
# Batch[0] - loss: 0.058227  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  4.8828125e-07
# INFO:impchat:lr to:4.8828125e-07
# Batch[500] - loss: 0.218957  batch_size:30
# Batch[1000] - loss: 0.121989  batch_size:30
# Batch[1500] - loss: 0.174548  batch_size:30
# Batch[2000] - loss: 0.240982  batch_size:30
# Batch[2500] - loss: 0.139526  batch_size:30
# Batch[3000] - loss: 0.200859  batch_size:30
# Batch[3500] - loss: 0.288787  batch_size:30
# Batch[4000] - loss: 0.090780  batch_size:30
# Batch[4500] - loss: 0.212965  batch_size:30
# Batch[5000] - loss: 0.313876  batch_size:30
# Batch[5500] - loss: 0.093936  batch_size:30
# Batch[6000] - loss: 0.140940  batch_size:30
# Batch[6500] - loss: 0.107393  batch_size:30
# Average loss:0.160754
# 8543it [04:41, 30.32it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487801970067743	MRR:0.6487801970067743	P@1:0.5037849227407523	R1:0.5037849227407523	R2:0.635437802403621	R5:0.852505072576869
#
# Epoch  36 / 100
# Batch[0] - loss: 0.136846  batch_size:30
# Batch[500] - loss: 0.040685  batch_size:30
# Batch[1000] - loss: 0.309019  batch_size:30
# Batch[1500] - loss: 0.220064  batch_size:30
# Batch[2000] - loss: 0.029517  batch_size:30
# Batch[2500] - loss: 0.154992  batch_size:30
# Batch[3000] - loss: 0.249203  batch_size:30
# Batch[3500] - loss: 0.028780  batch_size:30
# Batch[4000] - loss: 0.147580  batch_size:30
# Batch[4500] - loss: 0.062310  batch_size:30
# Batch[5000] - loss: 0.173887  batch_size:30
# Batch[5500] - loss: 0.055316  batch_size:30
# Batch[6000] - loss: 0.179527  batch_size:30
# Batch[6500] - loss: 0.081085  batch_size:30
# Average loss:0.160222
# 8543it [04:42, 30.26it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487327848261488	MRR:0.6487327848261488	P@1:0.5039019822069611	R1:0.5039019822069611	R2:0.6349695645387857	R5:0.8524660527547995
#
# Epoch  37 / 100
# Batch[0] - loss: 0.072366  batch_size:30
# Batch[500] - loss: 0.163491  batch_size:30
# Batch[1000] - loss: 0.314316  batch_size:30
# Batch[1500] - loss: 0.353337  batch_size:30
# Batch[2000] - loss: 0.132611  batch_size:30
# Batch[2500] - loss: 0.321621  batch_size:30
# Batch[3000] - loss: 0.178795  batch_size:30
# Batch[3500] - loss: 0.317958  batch_size:30
# Batch[4000] - loss: 0.209170  batch_size:30
# Batch[4500] - loss: 0.117881  batch_size:30
# Batch[5000] - loss: 0.261494  batch_size:30
# Batch[5500] - loss: 0.188878  batch_size:30
# Batch[6000] - loss: 0.082785  batch_size:30
# Batch[6500] - loss: 0.179551  batch_size:30
# Average loss:0.159994
# 8543it [04:42, 30.24it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487461940189708	MRR:0.6487461940189708	P@1:0.5038239425628219	R1:0.5038239425628219	R2:0.6350866240049945	R5:0.852309973466521
#
# Epoch  38 / 100
# Batch[0] - loss: 0.165122  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  2.44140625e-07
# INFO:impchat:lr to:2.44140625e-07
# Batch[500] - loss: 0.084387  batch_size:30
# Batch[1000] - loss: 0.202006  batch_size:30
# Batch[1500] - loss: 0.233100  batch_size:30
# Batch[2000] - loss: 0.032216  batch_size:30
# Batch[2500] - loss: 0.035314  batch_size:30
# Batch[3000] - loss: 0.056481  batch_size:30
# Batch[3500] - loss: 0.277823  batch_size:30
# Batch[4000] - loss: 0.057868  batch_size:30
# Batch[4500] - loss: 0.207491  batch_size:30
# Batch[5000] - loss: 0.144006  batch_size:30
# Batch[5500] - loss: 0.025554  batch_size:30
# Batch[6000] - loss: 0.066777  batch_size:30
# Batch[6500] - loss: 0.170106  batch_size:30
# Average loss:0.160672
# 8543it [04:43, 30.13it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487324286928517	MRR:0.6487324286928517	P@1:0.5035117839862651	R1:0.5035117839862651	R2:0.635945060090526	R5:0.8527001716872171
#
# Epoch  39 / 100
# Batch[0] - loss: 0.345197  batch_size:30
# Batch[500] - loss: 0.265371  batch_size:30
# Batch[1000] - loss: 0.295646  batch_size:30
# Batch[1500] - loss: 0.104558  batch_size:30
# Batch[2000] - loss: 0.269305  batch_size:30
# Batch[2500] - loss: 0.072826  batch_size:30
# Batch[3000] - loss: 0.227891  batch_size:30
# Batch[3500] - loss: 0.147200  batch_size:30
# Batch[4000] - loss: 0.244172  batch_size:30
# Batch[4500] - loss: 0.509266  batch_size:30
# Batch[5000] - loss: 0.086898  batch_size:30
# Batch[5500] - loss: 0.157143  batch_size:30
# Batch[6000] - loss: 0.027177  batch_size:30
# Batch[6500] - loss: 0.240278  batch_size:30
# Average loss:0.160497
# 8543it [04:42, 30.24it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6488152219422986	MRR:0.6488152219422986	P@1:0.5038629623848915	R1:0.5038629623848915	R2:0.6353987825815515	R5:0.852505072576869
#
# Epoch  40 / 100
# Batch[0] - loss: 0.110197  batch_size:30
# Batch[500] - loss: 0.108715  batch_size:30
# Batch[1000] - loss: 0.333791  batch_size:30
# Batch[1500] - loss: 0.035221  batch_size:30
# Batch[2000] - loss: 0.166710  batch_size:30
# Batch[2500] - loss: 0.242943  batch_size:30
# Batch[3000] - loss: 0.283975  batch_size:30
# Batch[3500] - loss: 0.052119  batch_size:30
# Batch[4000] - loss: 0.040809  batch_size:30
# Batch[4500] - loss: 0.081606  batch_size:30
# Batch[5000] - loss: 0.179043  batch_size:30
# Batch[5500] - loss: 0.055595  batch_size:30
# Batch[6000] - loss: 0.211334  batch_size:30
# Batch[6500] - loss: 0.229497  batch_size:30
# Average loss:0.160532
# 8543it [04:43, 30.10it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487466430566057	MRR:0.6487466430566057	P@1:0.5038239425628219	R1:0.5038239425628219	R2:0.635242703293273	R5:0.8522319338223817
#
# Epoch  41 / 100
# Batch[0] - loss: 0.139568  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  1.220703125e-07
# INFO:impchat:lr to:1.220703125e-07
# Batch[500] - loss: 0.218026  batch_size:30
# Batch[1000] - loss: 0.080967  batch_size:30
# Batch[1500] - loss: 0.267168  batch_size:30
# Batch[2000] - loss: 0.068848  batch_size:30
# Batch[2500] - loss: 0.191209  batch_size:30
# Batch[3000] - loss: 0.167220  batch_size:30
# Batch[3500] - loss: 0.041540  batch_size:30
# Batch[4000] - loss: 0.047341  batch_size:30
# Batch[4500] - loss: 0.056474  batch_size:30
# Batch[5000] - loss: 0.048448  batch_size:30
# Batch[5500] - loss: 0.047760  batch_size:30
# Batch[6000] - loss: 0.236375  batch_size:30
# Batch[6500] - loss: 0.162141  batch_size:30
# Average loss:0.160635
# 8543it [04:42, 30.29it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487305396379737	MRR:0.6487305396379737	P@1:0.5034337443421258	R1:0.5034337443421258	R2:0.6360230997346652	R5:0.8528172311534259
#
# Epoch  42 / 100
# Batch[0] - loss: 0.085652  batch_size:30
# Batch[500] - loss: 0.181524  batch_size:30
# Batch[1000] - loss: 0.244838  batch_size:30
# Batch[1500] - loss: 0.210210  batch_size:30
# Batch[2000] - loss: 0.133118  batch_size:30
# Batch[2500] - loss: 0.268361  batch_size:30
# Batch[3000] - loss: 0.175259  batch_size:30
# Batch[3500] - loss: 0.095410  batch_size:30
# Batch[4000] - loss: 0.210772  batch_size:30
# Batch[4500] - loss: 0.065288  batch_size:30
# Batch[5000] - loss: 0.288036  batch_size:30
# Batch[5500] - loss: 0.238214  batch_size:30
# Batch[6000] - loss: 0.178231  batch_size:30
# Batch[6500] - loss: 0.333113  batch_size:30
# Average loss:0.160533
# 8543it [04:42, 30.21it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487033806030889	MRR:0.6487033806030889	P@1:0.5034337443421258	R1:0.5034337443421258	R2:0.635945060090526	R5:0.8527001716872171
#
# Epoch  43 / 100
# Batch[0] - loss: 0.198265  batch_size:30
# Batch[500] - loss: 0.082834  batch_size:30
# Batch[1000] - loss: 0.074383  batch_size:30
# Batch[1500] - loss: 0.051591  batch_size:30
# Batch[2000] - loss: 0.042437  batch_size:30
# Batch[2500] - loss: 0.399084  batch_size:30
# Batch[3000] - loss: 0.051293  batch_size:30
# Batch[3500] - loss: 0.072390  batch_size:30
# Batch[4000] - loss: 0.165563  batch_size:30
# Batch[4500] - loss: 0.373573  batch_size:30
# Batch[5000] - loss: 0.099992  batch_size:30
# Batch[5500] - loss: 0.211119  batch_size:30
# Batch[6000] - loss: 0.194325  batch_size:30
# Batch[6500] - loss: 0.200576  batch_size:30
# Average loss:0.160585
# 8543it [04:42, 30.26it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487767130940896	MRR:0.6487767130940896	P@1:0.503706883096613	R1:0.503706883096613	R2:0.6356329015139691	R5:0.8527001716872171
#
# Epoch  44 / 100
# Batch[0] - loss: 0.367684  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  6.103515625e-08
# INFO:impchat:lr to:6.103515625e-08
# Batch[500] - loss: 0.111940  batch_size:30
# Batch[1000] - loss: 0.119640  batch_size:30
# Batch[1500] - loss: 0.183686  batch_size:30
# Batch[2000] - loss: 0.329654  batch_size:30
# Batch[2500] - loss: 0.160078  batch_size:30
# Batch[3000] - loss: 0.244898  batch_size:30
# Batch[3500] - loss: 0.241415  batch_size:30
# Batch[4000] - loss: 0.266091  batch_size:30
# Batch[4500] - loss: 0.269291  batch_size:30
# Batch[5000] - loss: 0.095286  batch_size:30
# Batch[5500] - loss: 0.235146  batch_size:30
# Batch[6000] - loss: 0.196335  batch_size:30
# Batch[6500] - loss: 0.106503  batch_size:30
# Average loss:0.160738
# 8543it [04:43, 30.16it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487705039874821	MRR:0.6487705039874821	P@1:0.5035117839862651	R1:0.5035117839862651	R2:0.6361011393788044	R5:0.8527782113313563
# INFO:impchat:Best Result:
# ...
#
# Epoch  92 / 100
# Batch[0] - loss: 0.189166  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  1.862645149230957e-12
# INFO:impchat:lr to:1.862645149230957e-12
# Batch[500] - loss: 0.323278  batch_size:30
# Batch[1000] - loss: 0.035005  batch_size:30
# Batch[1500] - loss: 0.156663  batch_size:30
# Batch[2000] - loss: 0.037490  batch_size:30
# Batch[2500] - loss: 0.096716  batch_size:30
# Batch[3000] - loss: 0.253114  batch_size:30
# Batch[3500] - loss: 0.209551  batch_size:30
# Batch[4000] - loss: 0.156538  batch_size:30
# Batch[4500] - loss: 0.163655  batch_size:30
# Batch[5000] - loss: 0.192760  batch_size:30
# Batch[5500] - loss: 0.108478  batch_size:30
# Batch[6000] - loss: 0.204415  batch_size:30
# Batch[6500] - loss: 0.067510  batch_size:30
# Average loss:0.160722
# 8543it [04:43, 30.14it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487675775008271	MRR:0.6487675775008271	P@1:0.5035117839862651	R1:0.5035117839862651	R2:0.6360621195567349	R5:0.8528562509754956
#
# Epoch  93 / 100
# Batch[0] - loss: 0.160606  batch_size:30
# Batch[500] - loss: 0.139392  batch_size:30
# Batch[1000] - loss: 0.096054  batch_size:30
# Batch[1500] - loss: 0.019728  batch_size:30
# Batch[2000] - loss: 0.342403  batch_size:30
# Batch[2500] - loss: 0.064816  batch_size:30
# Batch[3000] - loss: 0.089771  batch_size:30
# Batch[3500] - loss: 0.175397  batch_size:30
# Batch[4000] - loss: 0.121486  batch_size:30
# Batch[4500] - loss: 0.155451  batch_size:30
# Batch[5000] - loss: 0.149100  batch_size:30
# Batch[5500] - loss: 0.120152  batch_size:30
# Batch[6000] - loss: 0.080009  batch_size:30
# Batch[6500] - loss: 0.217707  batch_size:30
# Average loss:0.160511
# 8543it [04:42, 30.20it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487448159379531	MRR:0.6487448159379531	P@1:0.5034727641641954	R1:0.5034727641641954	R2:0.6360621195567349	R5:0.8528562509754956
#
# Epoch  94 / 100
# Batch[0] - loss: 0.036038  batch_size:30
# Batch[500] - loss: 0.032270  batch_size:30
# Batch[1000] - loss: 0.099155  batch_size:30
# Batch[1500] - loss: 0.111132  batch_size:30
# Batch[2000] - loss: 0.205558  batch_size:30
# Batch[2500] - loss: 0.060399  batch_size:30
# Batch[3000] - loss: 0.201244  batch_size:30
# Batch[3500] - loss: 0.301762  batch_size:30
# Batch[4000] - loss: 0.236235  batch_size:30
# Batch[4500] - loss: 0.270529  batch_size:30
# Batch[5000] - loss: 0.121525  batch_size:30
# Batch[5500] - loss: 0.120326  batch_size:30
# Batch[6000] - loss: 0.262213  batch_size:30
# Batch[6500] - loss: 0.215478  batch_size:30
# Average loss:0.160694
# 8543it [04:42, 30.21it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487675775008271	MRR:0.6487675775008271	P@1:0.5035117839862651	R1:0.5035117839862651	R2:0.6360621195567349	R5:0.8528562509754956
#
# Epoch  95 / 100
# Batch[0] - loss: 0.242204  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  9.313225746154785e-13
# INFO:impchat:lr to:9.313225746154785e-13
# Batch[500] - loss: 0.234494  batch_size:30
# Batch[1000] - loss: 0.210361  batch_size:30
# Batch[1500] - loss: 0.196220  batch_size:30
# Batch[2000] - loss: 0.179895  batch_size:30
# Batch[2500] - loss: 0.232244  batch_size:30
# Batch[3000] - loss: 0.105618  batch_size:30
# Batch[3500] - loss: 0.158975  batch_size:30
# Batch[4000] - loss: 0.170027  batch_size:30
# Batch[4500] - loss: 0.215202  batch_size:30
# Batch[5000] - loss: 0.121416  batch_size:30
# Batch[5500] - loss: 0.242105  batch_size:30
# Batch[6000] - loss: 0.110779  batch_size:30
# Batch[6500] - loss: 0.075256  batch_size:30
# Average loss:0.160779
# 8543it [04:42, 30.27it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487643258489879	MRR:0.6487643258489879	P@1:0.5035117839862651	R1:0.5035117839862651	R2:0.6360621195567349	R5:0.8528562509754956
#
# Epoch  96 / 100
# Batch[0] - loss: 0.063078  batch_size:30
# Batch[500] - loss: 0.122928  batch_size:30
# Batch[1000] - loss: 0.167084  batch_size:30
# Batch[1500] - loss: 0.146242  batch_size:30
# Batch[2000] - loss: 0.261226  batch_size:30
# Batch[2500] - loss: 0.082688  batch_size:30
# Batch[3000] - loss: 0.048428  batch_size:30
# Batch[3500] - loss: 0.054750  batch_size:30
# Batch[4000] - loss: 0.119370  batch_size:30
# Batch[4500] - loss: 0.107163  batch_size:30
# Batch[5000] - loss: 0.058846  batch_size:30
# Batch[5500] - loss: 0.264358  batch_size:30
# Batch[6000] - loss: 0.233571  batch_size:30
# Batch[6500] - loss: 0.221213  batch_size:30
# Average loss:0.160585
# 8543it [04:42, 30.19it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487675775008271	MRR:0.6487675775008271	P@1:0.5035117839862651	R1:0.5035117839862651	R2:0.6360621195567349	R5:0.8528562509754956
#
# Epoch  97 / 100
# Batch[0] - loss: 0.042760  batch_size:30
# Batch[500] - loss: 0.175251  batch_size:30
# Batch[1000] - loss: 0.154545  batch_size:30
# Batch[1500] - loss: 0.281390  batch_size:30
# Batch[2000] - loss: 0.090024  batch_size:30
# Batch[2500] - loss: 0.066103  batch_size:30
# Batch[3000] - loss: 0.121715  batch_size:30
# Batch[3500] - loss: 0.261417  batch_size:30
# Batch[4000] - loss: 0.037656  batch_size:30
# Batch[4500] - loss: 0.240688  batch_size:30
# Batch[5000] - loss: 0.253283  batch_size:30
# Batch[5500] - loss: 0.161891  batch_size:30
# Batch[6000] - loss: 0.456010  batch_size:30
# Batch[6500] - loss: 0.047116  batch_size:30
# Average loss:0.160567
# 8543it [04:43, 30.18it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487675775008271	MRR:0.6487675775008271	P@1:0.5035117839862651	R1:0.5035117839862651	R2:0.6360621195567349	R5:0.8528562509754956
#
# Epoch  98 / 100
# Batch[0] - loss: 0.069170  batch_size:30
# INFO:impchat:Reload the best model...
# Decay learning rate to:  4.656612873077393e-13
# INFO:impchat:lr to:4.656612873077393e-13
# Batch[500] - loss: 0.254273  batch_size:30
# Batch[1000] - loss: 0.136878  batch_size:30
# Batch[1500] - loss: 0.192982  batch_size:30
# Batch[2000] - loss: 0.227199  batch_size:30
# Batch[2500] - loss: 0.075941  batch_size:30
# Batch[3000] - loss: 0.043558  batch_size:30
# Batch[3500] - loss: 0.162301  batch_size:30
# Batch[4000] - loss: 0.087653  batch_size:30
# Batch[4500] - loss: 0.238185  batch_size:30
# Batch[5000] - loss: 0.081016  batch_size:30
# Batch[5500] - loss: 0.233803  batch_size:30
# Batch[6000] - loss: 0.411721  batch_size:30
# Batch[6500] - loss: 0.164614  batch_size:30
# Average loss:0.160740
# 8543it [04:43, 30.15it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487675775008271	MRR:0.6487675775008271	P@1:0.5035117839862651	R1:0.5035117839862651	R2:0.6360621195567349	R5:0.8528562509754956
#
# Epoch  99 / 100
# Batch[0] - loss: 0.134597  batch_size:30
# Batch[500] - loss: 0.082152  batch_size:30
# Batch[1000] - loss: 0.219599  batch_size:30
# Batch[1500] - loss: 0.137372  batch_size:30
# Batch[2000] - loss: 0.239280  batch_size:30
# Batch[2500] - loss: 0.298972  batch_size:30
# Batch[3000] - loss: 0.194319  batch_size:30
# Batch[3500] - loss: 0.071524  batch_size:30
# Batch[4000] - loss: 0.119101  batch_size:30
# Batch[4500] - loss: 0.230943  batch_size:30
# Batch[5000] - loss: 0.158378  batch_size:30
# Batch[5500] - loss: 0.392175  batch_size:30
# Batch[6000] - loss: 0.046269  batch_size:30
# Batch[6500] - loss: 0.062976  batch_size:30
# Average loss:0.160618
# 8543it [04:42, 30.19it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487675775008271	MRR:0.6487675775008271	P@1:0.5035117839862651	R1:0.5035117839862651	R2:0.6360621195567349	R5:0.8528562509754956
#
# Epoch  100 / 100
# Batch[0] - loss: 0.038089  batch_size:30
# Batch[500] - loss: 0.086680  batch_size:30
# Batch[1000] - loss: 0.156382  batch_size:30
# Batch[1500] - loss: 0.403490  batch_size:30
# Batch[2000] - loss: 0.049055  batch_size:30
# Batch[2500] - loss: 0.152896  batch_size:30
# Batch[3000] - loss: 0.286145  batch_size:30
# Batch[3500] - loss: 0.263398  batch_size:30
# Batch[4000] - loss: 0.148257  batch_size:30
# Batch[4500] - loss: 0.226584  batch_size:30
# Batch[5000] - loss: 0.316020  batch_size:30
# Batch[5500] - loss: 0.049014  batch_size:30
# Batch[6000] - loss: 0.146370  batch_size:30
# Batch[6500] - loss: 0.066916  batch_size:30
# Average loss:0.160755
# 8543it [04:42, 30.20it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487643258489879	MRR:0.6487643258489879	P@1:0.5035117839862651	R1:0.5035117839862651	R2:0.6360621195567349	R5:0.8528562509754956
# IMPChat(
#   (word_embedding): Embedding(61909, 200, padding_idx=0)
#   (selector_transformer): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (linear_word): Linear(in_features=100, out_features=1, bias=True)
#   (linear_score): Linear(in_features=2, out_features=1, bias=True)
#   (transformer_r): ModuleList(
#     (0): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (1): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (2): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#   )
#   (transformer_rp): ModuleList(
#     (0): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (1): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (2): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (3): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#   )
#   (transformer_utt): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (transformer_res): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (transformer_ur): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (transformer_ru): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (cnn_2d_1): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (maxpooling1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (cnn_2d_2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (maxpooling2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (cnn_2d_3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (maxpooling3): MaxPool2d(kernel_size=(3, 3), stride=(3, 3), padding=0, dilation=1, ceil_mode=False)
#   (cnn_2d_4): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#   (cnn_2d_5): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (cnn_2d_6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (affine2): Linear(in_features=576, out_features=200, bias=True)
#   (affine3): Linear(in_features=576, out_features=200, bias=True)
#   (gru_acc): GRU(200, 300, batch_first=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=200, out_features=300, bias=True)
#     (linear2): Linear(in_features=300, out_features=1, bias=True)
#   )
#   (affine_out): Linear(in_features=500, out_features=1, bias=True)
#   (tanh): Tanh()
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# X_utterances:  torch.Size([256280, 29, 50])
# X_responses:  torch.Size([256280, 50])
# INFO:impchat:IMPChat(
#   (word_embedding): Embedding(61909, 200, padding_idx=0)
#   (selector_transformer): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (linear_word): Linear(in_features=100, out_features=1, bias=True)
#   (linear_score): Linear(in_features=2, out_features=1, bias=True)
#   (transformer_r): ModuleList(
#     (0): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (1): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (2): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#   )
#   (transformer_rp): ModuleList(
#     (0): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (1): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (2): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (3): TransformerBlock(
#       (relu): ReLU()
#       (linear1): Linear(in_features=200, out_features=200, bias=True)
#       (linear2): Linear(in_features=200, out_features=200, bias=True)
#     )
#   )
#   (transformer_utt): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (transformer_res): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (transformer_ur): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (transformer_ru): TransformerBlock(
#     (relu): ReLU()
#     (linear1): Linear(in_features=200, out_features=200, bias=True)
#     (linear2): Linear(in_features=200, out_features=200, bias=True)
#   )
#   (cnn_2d_1): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (maxpooling1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (cnn_2d_2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (maxpooling2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (cnn_2d_3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (maxpooling3): MaxPool2d(kernel_size=(3, 3), stride=(3, 3), padding=0, dilation=1, ceil_mode=False)
#   (cnn_2d_4): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#   (cnn_2d_5): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (cnn_2d_6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (affine2): Linear(in_features=576, out_features=200, bias=True)
#   (affine3): Linear(in_features=576, out_features=200, bias=True)
#   (gru_acc): GRU(200, 300, batch_first=True)
#   (attention): Attention(
#     (linear1): Linear(in_features=200, out_features=300, bias=True)
#     (linear2): Linear(in_features=300, out_features=1, bias=True)
#   )
#   (affine_out): Linear(in_features=500, out_features=1, bias=True)
#   (tanh): Tanh()
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# 8543it [04:43, 30.14it/s]
# INFO:impchat:Evaluation Result:
#  MAP:0.6487480675897923	MRR:0.6487480675897923	P@1:0.5034727641641954	R1:0.5034727641641954	R2:0.6360621195567349	R5:0.8528562509754956
# use time:  1659.441630613804  min
